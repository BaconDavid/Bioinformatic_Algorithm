# %%
import imp
import fastcluster
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from fastcluster import linkage
from scipy.cluster.hierarchy import dendrogram
from scipy.spatial.distance import pdist

# %%
# 1. 加载鸢尾花数据集
iris = load_iris()
X = iris.data  # shape: (150, 4)

# 2. 使用 fastcluster 进行层次聚类
# linkage 方法可以是: "single", "complete", "average", "weighted", "ward", etc.
Z = fastcluster.linkage(X)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 7
#       3 X = iris.data  # shape: (150, 4)
#       5 # 2. 使用 fastcluster 进行层次聚类
#       6 # linkage 方法可以是: "single", "complete", "average", "weighted", "ward", etc.
# ----> 7 Z = fastcluster.linkage(X)
#
# File ~/mamba/envs/chumby/lib/python3.10/site-packages/fastcluster.py:244, in linkage(X, method, metric, preserve_input)
#     242     assert X.ndim==2
#     243     N = len(X)
# --> 244     X = pdist(X, metric=metric)
#     245     X = array(X, dtype=double, order='C', subok=True)
#     246 Z = empty((N-1,4))
#
# File ~/mamba/envs/chumby/lib/python3.10/site-packages/fastcluster.py:33, in pdist(*args, **kwargs)
#      32 def pdist(*args, **kwargs):
# ---> 33     raise ImportError('The fastcluster.linkage function cannot process '
#      34                       'vector data since the function '
#      35                       'scipy.spatial.distance.pdist could not be  '
#      36                       'imported.')
#
# ImportError: The fastcluster.linkage function cannot process vector data since the function scipy.spatial.distance.pdist could not be  imported.
